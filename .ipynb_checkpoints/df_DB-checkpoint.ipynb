# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# %%
# File to Load (Remember to change these)
nfldata_csv = "C:/Users/admin/Documents/SMU/NFL-QB-Analytics/Assets/Data_Files/Cleaned_QB_data.csv"

# Read the City and Ride Data
nfldata = pd.read_csv(nfldata_csv)
nfldata.head()
# Out:
#    Year             Name          Season  TD Passes  Passing Yards  Wins
# 0  1970  Arrington, Rick  Regular Season          1            328     3
# 1  1970   Beathard, Pete  Regular Season          2            114     8
# 2  1970      Belden, Bob  Regular Season          0              0     2
# 3  1970  Cappleman, Bill  Regular Season          0             49     2
# 4  1970   Carter, Virgil      Postseason          0             64     0

# %%
nfldata_df = nfldata.groupby(["Year", "Name"])["Wins"].sum().reset_index().sort_values(by = "Wins",ascending = False)

nfldata_df
# Out:
#       Year                 Name  Wins
# 2605  2015          Newton, Cam    21
# 2446  2013      Wilson, Russell    21
# 2545  2015      Anderson, Derek    20
# 2663  2016     Garoppolo, Jimmy    20
# 2634  2015            Webb, Joe    20
# 1864  2007         Cassel, Matt    20
# 1859  2007           Brady, Tom    20
# 2389  2013    Jackson, Tarvaris    20
# 2023  2009          Brees, Drew    19
# 1559  2002          King, Shaun    18
# 1555  2002        Johnson, Brad    18
# 2243  2011       Rodgers, Aaron    18
# 608   1984      Cavanaugh, Matt    18
# 693   1985        Tomczak, Mike    18
# 2003  2008  Roethlisberger, Ben    18
# 2197  2011          Flynn, Matt    18
# 2620  2015      Siemian, Trevor    18
# 1557  2002         Johnson, Rob    18
# 2591  2015      Manning, Peyton    18
# 2405  2013      Manning, Peyton    18
# 2451  2014           Brady, Tom    18
# 2607  2015      Osweiler, Brock    18
# 1654  2004           Brady, Tom    17
# 2176  2011           Brady, Tom    17
# ...

# %%
nfldata_df = nfldata.groupby(["Year", "Name"])["Passing Yards"].count().reset_index().sort_values(by = "Passing Yards",ascending = False)

nfldata_df
# Out:
#       Year                Name  Passing Yards
# 2423  2013      Rivers, Philip              4
# 2220  2011        Manning, Eli              4
# 1544  2002        Garcia, Jeff              4
# 2430  2013         Smith, Alex              4
# 2636  2015     Wilson, Russell              4
# 1543  2002        Gannon, Rich              4
# 1584  2002          Vick, Mike              4
# 1838  2006      Rivers, Philip              4
# 2036  2009        Favre, Brett              4
# 2446  2013     Wilson, Russell              4
# 2551  2015  Bridgewater, Teddy              4
# 2359  2013         Brees, Drew              4
# 2451  2014          Brady, Tom              4
# 2187  2011        Dalton, Andy              4
# 2548  2015          Brady, Tom              4
# 1539  2002        Favre, Brett              4
# 2177  2011         Brees, Drew              4
# 2176  2011          Brady, Tom              4
# 2461  2014        Dalton, Andy              4
# ...
